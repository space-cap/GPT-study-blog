# %%
from dotenv import load_dotenv
import os

load_dotenv()

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate


llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash", 
    temperature=0.1,
    )

memory = ConversationSummaryBufferMemory(
    llm=llm, 
    max_token_limit=80,
    )

chain = LLMChain(
    llm=llm,
    memory=memory,
    prompt=PromptTemplate.from_template("{question}"),
    verbose=True,
)
# Out:
# C:\Users\sman\AppData\Local\Temp\ipykernel_24356\1580532532.py:17: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(
# C:\Users\sman\AppData\Local\Temp\ipykernel_24356\1580532532.py:22: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(

# %%
chain.predict(question="My name is Nico")
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# My name is Nico
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chain.predict(question="My name is Nico")
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     158     self._validate_inputs(inputs)
#     159     outputs = (
#     160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
# --> 165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:466, in Chain.prep_outputs(self, inputs, outputs, return_only_outputs)
#     464 self._validate_outputs(outputs)
#     465 if self.memory is not None:
# --> 466     self.memory.save_context(inputs, outputs)
#     467 if return_only_outputs:
#     468     return outputs
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\memory\summary_buffer.py:96, in ConversationSummaryBufferMemory.save_context(self, inputs, outputs)
#      94 """Save context from this conversation to buffer."""
#      95 super().save_context(inputs, outputs)
# ---> 96 self.prune()
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\memory\summary_buffer.py:108, in ConversationSummaryBufferMemory.prune(self)
#     106 """Prune buffer if it exceeds max token limit"""
#     107 buffer = self.chat_memory.messages
# --> 108 curr_buffer_length = self.llm.get_num_tokens_from_messages(buffer)
#     109 if curr_buffer_length > self.max_token_limit:
#     110     pruned_memory = []
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\language_models\base.py:393, in BaseLanguageModel.get_num_tokens_from_messages(self, messages, tools)
#     388 if tools is not None:
#     389     warnings.warn(
#     390         "Counting tokens in tool schemas is not yet supported. Ignoring tools.",
#     391         stacklevel=2,
#     392     )
# --> 393 return sum([self.get_num_tokens(get_buffer_string([m])) for m in messages])
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_google_genai\chat_models.py:1219, in ChatGoogleGenerativeAI.get_num_tokens(self, text)
#    1208 def get_num_tokens(self, text: str) -> int:
#    1209     """Get the number of tokens present in the text.
#    1210
#    1211     Useful for checking if an input will fit in a model's context window.
#    (...)
#    1217         The integer number of tokens in the text.
#    1218     """
# -> 1219     result = self.client.count_tokens(
#    1220         model=self.model, contents=[Content(parts=[Part(text=text)])]
#    1221     )
#    1222     return result.total_tokens
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1505, in GenerativeServiceClient.count_tokens(self, request, model, contents, retry, timeout, metadata)
#    1502 self._validate_universe_domain()
#    1504 # Send the request.
# -> 1505 response = rpc(
#    1506     request,
#    1507     retry=retry,
#    1508     timeout=timeout,
#    1509     metadata=metadata,
#    1510 )
#    1512 # Done; return the response.
#    1513 return response
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\grpc\_channel.py:1178, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1166 def __call__(
#    1167     self,
#    1168     request: Any,
#    (...)
#    1173     compression: Optional[grpc.Compression] = None,
#    1174 ) -> Any:
#    1175     (
#    1176         state,
#    1177         call,
# -> 1178     ) = self._blocking(
#    1179         request, timeout, metadata, credentials, wait_for_ready, compression
#    1180     )
#    1181     return _end_unary_response_blocking(state, call, False, None)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\grpc\_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:62, in grpc._cython.cygrpc._internal_latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:58, in grpc._cython.cygrpc._interpret_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/tag.pyx.pxi:71, in grpc._cython.cygrpc._BatchOperationTag.event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/operation.pyx.pxi:138, in grpc._cython.cygrpc.ReceiveInitialMetadataOperation.un_c()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/metadata.pyx.pxi:69, in grpc._cython.cygrpc._metadata()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/metadata.pyx.pxi:70, in genexpr()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/metadata.pyx.pxi:64, in grpc._cython.cygrpc._metadatum()
#
# File <string>:1, in <lambda>(_cls, key, value)
#
# KeyboardInterrupt:

# %%
chain.predict(question="I live in Seoul")
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# I live in Seoul
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 chain.predict(question="I live in Seoul")
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_google_genai\chat_models.py:946, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     920 def _generate(
#     921     self,
#     922     messages: List[BaseMessage],
#    (...)
#     933     **kwargs: Any,
#     934 ) -> ChatResult:
#     935     request = self._prepare_request(
#     936         messages,
#     937         stop=stop,
#    (...)
#     944         tool_choice=tool_choice,
#     945     )
# --> 946     response: GenerateContentResponse = _chat_with_retry(
#     947         request=request,
#     948         **kwargs,
#     949         generation_method=self.client.generate_content,
#     950         metadata=self.default_metadata,
#     951     )
#     952     return _response_to_result(response)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_google_genai\chat_models.py:196, in _chat_with_retry(generation_method, **kwargs)
#     193     except Exception as e:
#     194         raise e
# --> 196 return _chat_with_retry(**kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\tenacity\__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File C:\python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\langchain_google_genai\chat_models.py:178, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     175 @retry_decorator
#     176 def _chat_with_retry(**kwargs: Any) -> Any:
#     177     try:
# --> 178         return generation_method(**kwargs)
#     179     # Do not retry for these errors.
#     180     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:830, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     827 self._validate_universe_domain()
#     829 # Send the request.
# --> 830 response = rpc(
#     831     request,
#     832     retry=retry,
#     833     timeout=timeout,
#     834     metadata=metadata,
#     835 )
#     837 # Done; return the response.
#     838 return response
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\grpc\_channel.py:1178, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1166 def __call__(
#    1167     self,
#    1168     request: Any,
#    (...)
#    1173     compression: Optional[grpc.Compression] = None,
#    1174 ) -> Any:
#    1175     (
#    1176         state,
#    1177         call,
# -> 1178     ) = self._blocking(
#    1179         request, timeout, metadata, credentials, wait_for_ready, compression
#    1180     )
#    1181     return _end_unary_response_blocking(state, call, False, None)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\grpc\_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
