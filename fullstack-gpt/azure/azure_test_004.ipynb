# %%
import os
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from openai import AzureOpenAI

token_provider = get_bearer_token_provider(DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

# %%
token_provider
# Out:
# <function azure.identity._bearer_token_provider.get_bearer_token_provider.<locals>.wrapper() -> str>

# %%
client = AzureOpenAI(
    azure_ad_token_provider=token_provider,
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_version="2024-05-01-preview",
)

# %%
# Create an assistant
assistant = client.beta.assistants.create(
    name="Math Assist",
    instructions="You are an AI assistant that can write code to help answer math questions.",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4-1106-preview" # You must replace this value with the deployment name for your model.
)
# Out:
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Create an assistant
# ----> 2 assistant = client.beta.assistants.create(
#       3     name="Math Assist",
#       4     instructions="You are an AI assistant that can write code to help answer math questions.",
#       5     tools=[{"type": "code_interpreter"}],
#       6     model="gpt-4-1106-preview" # You must replace this value with the deployment name for your model.
#       7 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\resources\beta\assistants.py:146, in Assistants.create(self, model, description, instructions, metadata, name, response_format, temperature, tool_resources, tools, top_p, extra_headers, extra_query, extra_body, timeout)
#      75 """
#      76 Create an assistant with a model and instructions.
#      77
#    (...)
#     143   timeout: Override the client-level default timeout for this request, in seconds
#     144 """
#     145 extra_headers = {"OpenAI-Beta": "assistants=v2", **(extra_headers or {})}
# --> 146 return self._post(
#     147     "/assistants",
#     148     body=maybe_transform(
#     149         {
#     150             "model": model,
#     151             "description": description,
#     152             "instructions": instructions,
#     153             "metadata": metadata,
#     154             "name": name,
#     155             "response_format": response_format,
#     156             "temperature": temperature,
#     157             "tool_resources": tool_resources,
#     158             "tools": tools,
#     159             "top_p": top_p,
#     160         },
#     161         assistant_create_params.AssistantCreateParams,
#     162     ),
#     163     options=make_request_options(
#     164         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     165     ),
#     166     cast_to=Assistant,
#     167 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\_base_client.py:980, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     977 input_options = model_copy(options)
#     979 cast_to = self._maybe_override_cast_to(cast_to, options)
# --> 980 options = self._prepare_options(options)
#     982 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
#     983 request = self._build_request(options, retries_taken=retries_taken)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\lib\azure.py:290, in AzureOpenAI._prepare_options(self, options)
#     287 options = model_copy(options)
#     288 options.headers = headers
# --> 290 azure_ad_token = self._get_azure_ad_token()
#     291 if azure_ad_token is not None:
#     292     if headers.get("Authorization") is None:
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\openai\lib\azure.py:274, in AzureOpenAI._get_azure_ad_token(self)
#     272 provider = self._azure_ad_token_provider
#     273 if provider is not None:
# --> 274     token = provider()
#     275     if not token or not isinstance(token, str):  # pyright: ignore[reportUnnecessaryIsInstance]
#     276         raise ValueError(
#     277             f"Expected `azure_ad_token_provider` argument to return a string but it returned {token}",
#     278         )
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\identity\_bearer_token_provider.py:43, in get_bearer_token_provider.<locals>.wrapper()
#      41 def wrapper() -> str:
#      42     request = _make_request()
# ---> 43     policy.on_request(request)
#      44     return request.http_request.headers["Authorization"][len("Bearer ") :]
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:132, in BearerTokenCredentialPolicy.on_request(self, request)
#     129 self._enforce_https(request)
#     131 if self._token is None or self._need_new_token:
# --> 132     self._request_token(*self._scopes)
#     133 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     134 self._update_headers(request.http_request.headers, bearer_token)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:108, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     101 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     102     """Request a new token from the credential.
#     103
#     104     This will call the credential's appropriate method to get a token and store it in the policy.
#     105
#     106     :param str scopes: The type of access needed.
#     107     """
# --> 108     self._token = self._get_token(*scopes, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:98, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      95         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      96             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# ---> 98     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#      99 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\identity\_credentials\default.py:255, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     252     return token_info
#     254 within_dac.set(True)
# --> 255 token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     256 within_dac.set(False)
#     257 return token_info
#
# File d:\workdir\github-space-cap\GPT-study-blog\fullstack-gpt\env\Lib\site-packages\azure\identity\_credentials\chained.py:219, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     211 message = (
#     212     self.__class__.__name__
#     213     + " failed to retrieve a token from the included credentials."
#    (...)
#     216     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     217 )
#     218 _LOGGER.warning(message)
# --> 219 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
